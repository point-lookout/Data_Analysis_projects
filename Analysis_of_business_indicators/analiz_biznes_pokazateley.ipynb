# %% [markdown]
# <div class="alert alert-info">
#
#
# <p style="text-align: center;"><font size="5"><b>АНАЛИЗ БИЗНЕС-ПОКАЗАТЕЛЕЙ МАРКЕТИНГОВОГО ПРИЛОЖЕНИЯ</b></font></p>

# %% [markdown]
# **Перед нами стоит цель проанализировать ряд параметров экономической активности развлекательного приложения Procrastinate Pro+, в частности эффективности её маркетинговой составляющей. Несмотря на существенные вложения в рекламу, последние несколько месяцев компания терпит убытки. Наша задача — разобраться в причинах и помочь компании выйти в плюс.**
#
# **Нам предстоит изучить:
# •	откуда приходят пользователи и какими устройствами они пользуются;
# •	сколько стоит привлечение пользователей из различных рекламных каналов;
# •	сколько денег приносит каждый клиент;
# •	когда расходы на привлечение клиента окупаются;
# •	какие факторы мешают привлечению клиентов.**

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#ЗАГРУЗКА-ДАННЫХ-И-ЗНАКОМСТВО-С-НИМИ" data-toc-modified-id="ЗАГРУЗКА-ДАННЫХ-И-ЗНАКОМСТВО-С-НИМИ-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>ЗАГРУЗКА ДАННЫХ И ЗНАКОМСТВО С НИМИ</a></span><ul class="toc-item"><li><span><a href="#Импорт-библиотек-и-загрузка-данных" data-toc-modified-id="Импорт-библиотек-и-загрузка-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Импорт библиотек и загрузка данных</a></span></li><li><span><a href="#Знакомство-с-датасетами" data-toc-modified-id="Знакомство-с-датасетами-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Знакомство с датасетами</a></span><ul class="toc-item"><li><span><a href="#Датасет-visits" data-toc-modified-id="Датасет-visits-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Датасет visits</a></span></li><li><span><a href="#Датасеты--orders-и-costs" data-toc-modified-id="Датасеты--orders-и-costs-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Датасеты  orders и costs</a></span></li></ul></li></ul></li><li><span><a href="#ПРЕДВАРИТЕЛЬНАЯ-ОБРАБОТКА-ДАННЫХ" data-toc-modified-id="ПРЕДВАРИТЕЛЬНАЯ-ОБРАБОТКА-ДАННЫХ-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>ПРЕДВАРИТЕЛЬНАЯ ОБРАБОТКА ДАННЫХ</a></span></li><li><span><a href="#ОПРЕДЕЛЕНИЕ-ФУНКЦИЙ-ДЛЯ-РАСЧЁТА-БИЗНЕС-ПОКАЗАТЕЛЕЙ" data-toc-modified-id="ОПРЕДЕЛЕНИЕ-ФУНКЦИЙ-ДЛЯ-РАСЧЁТА-БИЗНЕС-ПОКАЗАТЕЛЕЙ-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>ОПРЕДЕЛЕНИЕ ФУНКЦИЙ ДЛЯ РАСЧЁТА БИЗНЕС-ПОКАЗАТЕЛЕЙ</a></span><ul class="toc-item"><li><span><a href="#Зададим-функции-для-вычисления-значений-метрик:" data-toc-modified-id="Зададим-функции-для-вычисления-значений-метрик:-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Зададим функции для вычисления значений метрик:</a></span></li><li><span><a href="#Зададим-функции-для-построения-графиков:" data-toc-modified-id="Зададим-функции-для-построения-графиков:-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Зададим функции для построения графиков:</a></span></li></ul></li><li><span><a href="#ИССЛЕДОВАТЕЛЬСКИЙ-АНАЛИЗ-ДАННЫХ" data-toc-modified-id="ИССЛЕДОВАТЕЛЬСКИЙ-АНАЛИЗ-ДАННЫХ-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>ИССЛЕДОВАТЕЛЬСКИЙ АНАЛИЗ ДАННЫХ</a></span><ul class="toc-item"><li><span><a href="#Составим-профили-пользователей" data-toc-modified-id="Составим-профили-пользователей-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Составим профили пользователей</a></span></li><li><span><a href="#Выясним,-из-каких-стран-пользователи-приходят-в-приложение-и-на-какую-страну-приходится-больше-всего-платящих-пользователей." data-toc-modified-id="Выясним,-из-каких-стран-пользователи-приходят-в-приложение-и-на-какую-страну-приходится-больше-всего-платящих-пользователей.-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Выясним, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей.</a></span></li><li><span><a href="#Выясним,-какими-устройствами-пользуются-клиенты-и-какие-устройства-предпочитают-платящие-пользователи." data-toc-modified-id="Выясним,-какими-устройствами-пользуются-клиенты-и-какие-устройства-предпочитают-платящие-пользователи.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Выясним, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи.</a></span></li><li><span><a href="#Изучим-рекламные-источники-привлечения-и-определим-каналы,-из-которых-пришло-больше-всего-платящих-пользователей." data-toc-modified-id="Изучим-рекламные-источники-привлечения-и-определим-каналы,-из-которых-пришло-больше-всего-платящих-пользователей.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Изучим рекламные источники привлечения и определим каналы, из которых пришло больше всего платящих пользователей.</a></span></li></ul></li><li><span><a href="#МАРКЕТИНГОВЫЙ-АНАЛИЗ" data-toc-modified-id="МАРКЕТИНГОВЫЙ-АНАЛИЗ-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>МАРКЕТИНГОВЫЙ АНАЛИЗ</a></span><ul class="toc-item"><li><span><a href="#Посчитаем-общую-сумму-расходов-на-маркетинг." data-toc-modified-id="Посчитаем-общую-сумму-расходов-на-маркетинг.-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Посчитаем общую сумму расходов на маркетинг.</a></span></li><li><span><a href="#Выясним,-как-траты-распределены-по-рекламным-источникам." data-toc-modified-id="Выясним,-как-траты-распределены-по-рекламным-источникам.-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Выясним, как траты распределены по рекламным источникам.</a></span></li><li><span><a href="#Построим-визуализацию-динамики-изменения-расходов-во-времени-по-каждому-источнику." data-toc-modified-id="Построим-визуализацию-динамики-изменения-расходов-во-времени-по-каждому-источнику.-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Построим визуализацию динамики изменения расходов во времени по каждому источнику.</a></span></li><li><span><a href="#Узнаем,-сколько-в-среднем-стоило-привлечение-одного-пользователя-(CAC)-из-каждого-источника." data-toc-modified-id="Узнаем,-сколько-в-среднем-стоило-привлечение-одного-пользователя-(CAC)-из-каждого-источника.-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Узнаем, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника.</a></span></li></ul></li><li><span><a href="#ОЦЕНИМ-ОКУПАЕМОСТЬ-РЕКЛАМЫ" data-toc-modified-id="ОЦЕНИМ-ОКУПАЕМОСТЬ-РЕКЛАМЫ-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>ОЦЕНИМ ОКУПАЕМОСТЬ РЕКЛАМЫ</a></span><ul class="toc-item"><li><span><a href="#Проанализируем-окупаемость-рекламы-c-помощью-графиков-LTV-и-ROI,-а-также-графиков-динамики-LTV,-CAC-и-ROI." data-toc-modified-id="Проанализируем-окупаемость-рекламы-c-помощью-графиков-LTV-и-ROI,-а-также-графиков-динамики-LTV,-CAC-и-ROI.-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Проанализируем окупаемость рекламы c помощью графиков LTV и ROI, а также графиков динамики LTV, CAC и ROI.</a></span></li><li><span><a href="#Проверим-конверсию-пользователей-и-динамику-её-изменения.-То-же-самое-сделаем-с-удержанием-пользователей.-Построим-и-изучим-графики-конверсии-и-удержания." data-toc-modified-id="Проверим-конверсию-пользователей-и-динамику-её-изменения.-То-же-самое-сделаем-с-удержанием-пользователей.-Построим-и-изучим-графики-конверсии-и-удержания.-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Проверим конверсию пользователей и динамику её изменения. То же самое сделаем с удержанием пользователей. Построим и изучим графики конверсии и удержания.</a></span></li><li><span><a href="#Проанализируем-окупаемость-рекламы-с-разбивкой-по-устройствам." data-toc-modified-id="Проанализируем-окупаемость-рекламы-с-разбивкой-по-устройствам.-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Проанализируем окупаемость рекламы с разбивкой по устройствам.</a></span></li><li><span><a href="#Проанализируем-окупаемость-рекламы-с-разбивкой-по-странам." data-toc-modified-id="Проанализируем-окупаемость-рекламы-с-разбивкой-по-странам.-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Проанализируем окупаемость рекламы с разбивкой по странам.</a></span></li><li><span><a href="#Проанализируем-окупаемость-рекламы-с-разбивкой-по-рекламным-каналам." data-toc-modified-id="Проанализируем-окупаемость-рекламы-с-разбивкой-по-рекламным-каналам.-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Проанализируем окупаемость рекламы с разбивкой по рекламным каналам.</a></span></li><li><span><a href="#Ответы-на-вопросы" data-toc-modified-id="Ответы-на-вопросы-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Ответы на вопросы</a></span></li></ul></li><li><span><a href="#ОБЩИЙ-ВЫВОД" data-toc-modified-id="ОБЩИЙ-ВЫВОД-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>ОБЩИЙ ВЫВОД</a></span></li></ul></div>

# %% [markdown]
# <div class="alert alert-info">
#
# ## ЗАГРУЗКА ДАННЫХ И ЗНАКОМСТВО С НИМИ

# %% [markdown]
# ### Импорт библиотек и загрузка данных

# %% [markdown]
# **Для начала, импортируем библиотеки, которые понадобятся нам в работе:**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

# %% [markdown]
# **Затем сохраним имеющиеся датасеты:**

# %%
visits, orders, costs = (
        pd.read_csv (r'D:\Datasets_for_Git/visits_info_short.csv'),
        pd.read_csv (r'D:\Datasets_for_Git/orders_info_short.csv'),
        pd.read_csv (r'D:\Datasets_for_Git/costs_info_short.csv'))

# %% [markdown]
# ### Знакомство с датасетами

# %% [markdown]
# #### Датасет visits

# %%
#выведем десять строк датасета, воспользовавшись методом sample - шанс увидеть аномалию несколько выше при выводе "вразнобой"

visits.sample(10)
# Out:
#              User Id         Region   Device             Channel  \
# 162112  376193795590  United States   iPhone            FaceBoom
# 71967   679558218184  United States  Android             organic
# 45066   737665808546  United States   iPhone             organic
# 231859  294173616701        Germany  Android  OppleCreativeMedia
# 305353  363056511381             UK       PC             LeapBob
# 180623  467693593221  United States   iPhone            FaceBoom
# 17320   673033234731  United States  Android             organic
# 100660  169500946155  United States  Android             organic
# 92618   492262750271  United States   iPhone             organic
# 108963  327092604724  United States   iPhone              TipTop
#
#               Session Start          Session End
# 162112  2019-09-27 07:50:52  2019-09-27 08:06:21
# 71967   2019-07-10 11:13:01  2019-07-10 11:44:48
# 45066   2019-06-17 06:54:38  2019-06-17 06:56:00
# 231859  2019-06-21 01:01:45  2019-06-21 01:34:02
# ...

# %% [markdown]
# **Внешне всё выглядит упорядоченно. Глубже изучим структуру данных датасета:**

# %%
visits.shape
# Out:
# (309901, 6)

# %%
visits.columns
# Out:
# Index(['User Id', 'Region', 'Device', 'Channel', 'Session Start',
#        'Session End'],
#       dtype='object')

# %% [markdown]
# **Видим, что названия колонок написаны с пропусками и с заглавных букв, что не очень удобно в последующей работе с данными.**

# %%
visits.dtypes
# Out:
# User Id           int64
# Region           object
# Device           object
# Channel          object
# Session Start    object
# Session End      object
# dtype: object

# %% [markdown]
# **Видим, что тип данных во всех колонках - object. Надо будет привести колонки с датой к типу datetime.**

# %%
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB

# %% [markdown]
# **Предварительно наблюдаем отсутствие колонок с пропущенными данными. Для проверки выведем количество пропусков:**

# %%
visits.isna().sum()
# Out:
# User Id          0
# Region           0
# Device           0
# Channel          0
# Session Start    0
# Session End      0
# dtype: int64

# %%
#проверим наличие явных дубликатов

visits.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Пропущенные значения отсутствуют. Применим метод describe для того, чтобы увидеть возможные аномальные крайние значения.**

# %%
#применим параметр include='all' для отображения информации и по нечиленным типам данных

visits.describe(include='all')
# Out:
#              User Id         Region  Device  Channel        Session Start  \
# count   3.099010e+05         309901  309901   309901               309901
# unique           NaN              4       4       11               306813
# top              NaN  United States  iPhone  organic  2019-06-27 14:56:41
# freq             NaN         207327  112603   107760                    3
# mean    4.997664e+11            NaN     NaN      NaN                  NaN
# std     2.887899e+11            NaN     NaN      NaN                  NaN
# min     5.993260e+05            NaN     NaN      NaN                  NaN
# 25%     2.493691e+11            NaN     NaN      NaN                  NaN
# 50%     4.989906e+11            NaN     NaN      NaN                  NaN
# 75%     7.495211e+11            NaN     NaN      NaN                  NaN
# max     9.999996e+11            NaN     NaN      NaN                  NaN
#
#                 Session End
# count                309901
# ...

# %% [markdown]
# **Картина не очень показательна, т.к. присутствует много NAN'ов. Тем не менее, оставим, для полноты отображения информации. Явных аномалий не отображает.**

# %% [markdown]
# #### Датасеты  orders и costs

# %%
orders.sample(10)
# Out:
#             User Id             Event Dt  Revenue
# 17397  512465640593  2019-09-11 21:48:02     4.99
# 22784  841149330352  2019-10-07 00:17:30     4.99
# 17495  293149358744  2019-09-11 22:24:17     4.99
# 29639  173553705024  2019-06-19 22:47:55     4.99
# 18038  750419810153  2019-09-15 20:08:09     4.99
# 32184  656182549420  2019-08-02 13:09:45     4.99
# 1857   202451586137  2019-05-29 21:05:35     4.99
# 4957   699300306619  2019-06-26 00:16:15     4.99
# 33893  880169258499  2019-08-24 16:39:02     4.99
# 2390   386921589737  2019-06-03 05:44:58     4.99

# %%
orders.shape
# Out:
# (40212, 3)

# %%
orders.columns
# Out:
# Index(['User Id', 'Event Dt', 'Revenue'], dtype='object')

# %% [markdown]
# **Видим аналогичную проблему с написанием названий колонок.**

# %%
orders.dtypes
# Out:
# User Id       int64
# Event Dt     object
# Revenue     float64
# dtype: object

# %% [markdown]
# **Колонку Event Dt надо привести к типу datetime**

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB

# %%
orders.isna().sum()
# Out:
# User Id     0
# Event Dt    0
# Revenue     0
# dtype: int64

# %% [markdown]
# **Пропуски отсутствуют.**

# %%
#проверим наличие явных дубликатов

orders.duplicated().sum()
# Out:
# 0

# %%
orders.describe(include='all')
# Out:
#              User Id             Event Dt       Revenue
# count   4.021200e+04                40212  40212.000000
# unique           NaN                40163           NaN
# top              NaN  2019-10-26 06:49:22           NaN
# freq             NaN                    2           NaN
# mean    4.990295e+11                  NaN      5.370608
# std     2.860937e+11                  NaN      3.454208
# min     5.993260e+05                  NaN      4.990000
# 25%     2.511324e+11                  NaN      4.990000
# 50%     4.982840e+11                  NaN      4.990000
# 75%     7.433327e+11                  NaN      4.990000
# max     9.998954e+11                  NaN     49.990000

# %% [markdown]
# **Явных аномальных значений не наблюдаем.**

# %% [markdown]
# **Проделаем всё то же для costs:**

# %%
costs.sample(10)
# Out:
#               dt         Channel    costs
# 1148  2019-07-08         LeapBob   11.130
# 75    2019-07-15        FaceBoom  160.600
# 845   2019-09-03         YRabbit    2.730
# 489   2019-09-07  RocketSuperAds    6.175
# 635   2019-08-04          TipTop  417.000
# 447   2019-07-27  RocketSuperAds    9.555
# 647   2019-08-16          TipTop  342.000
# 1578  2019-09-16  WahooNetBanner   34.200
# 900   2019-05-01      AdNonSense   40.950
# 755   2019-06-05         YRabbit    6.000

# %%
costs.shape
# Out:
# (1800, 3)

# %%
costs.columns
# Out:
# Index(['dt', 'Channel', 'costs'], dtype='object')

# %% [markdown]
# **Знакомая проблема с написанием названий колонок.**

# %%
costs.dtypes
# Out:
# dt          object
# Channel     object
# costs      float64
# dtype: object

# %% [markdown]
# **Нужно будет привести колонку dt к типу datetime.**

# %%
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %%
costs.isna().sum()
# Out:
# dt         0
# Channel    0
# costs      0
# dtype: int64

# %%
#проверим наличие явных дубликатов

costs.duplicated().sum()
# Out:
# 0

# %%
costs.describe(include='all')
# Out:
#                 dt   Channel        costs
# count         1800      1800  1800.000000
# unique         180        10          NaN
# top     2019-05-01  FaceBoom          NaN
# freq            10       180          NaN
# mean           NaN       NaN    58.609611
# std            NaN       NaN   107.740223
# min            NaN       NaN     0.800000
# 25%            NaN       NaN     6.495000
# 50%            NaN       NaN    12.285000
# 75%            NaN       NaN    33.600000
# max            NaN       NaN   630.000000

# %% [markdown]
# **Пропуски отсутствуют, явных аномалий не обнаружено.**

# %% [markdown]
# <div class="alert alert-info">
#
# ## ПРЕДВАРИТЕЛЬНАЯ ОБРАБОТКА ДАННЫХ

# %% [markdown]
# **Поменяем названия колонок в датасетах на более удобочитаемые и приведём данные в колонках с датой к типу datetime:**

# %%
#используем метод map для приведения названий колонок к нижнему регистру
#затем заменим пробелы в названиях на нижнее подчёркивание

visits.columns = map(str.lower, visits.columns)
visits.columns = [i.replace (' ', '_') for i in visits.columns]

# %%
visits.columns
# Out:
# Index(['user_id', 'region', 'device', 'channel', 'session_start',
#        'session_end'],
#       dtype='object')

# %%
orders.columns = map(str.lower, orders.columns)
orders.columns = [i.replace (' ', '_') for i in orders.columns]

# %%
orders.columns
# Out:
# Index(['user_id', 'event_dt', 'revenue'], dtype='object')

# %%
costs.columns = map(str.lower, costs.columns)
costs.columns = [i.replace (' ', '_') for i in costs.columns]

# %%
costs.columns
# Out:
# Index(['dt', 'channel', 'costs'], dtype='object')

# %% [markdown]
# **Далее приведём колонки с датами к типу datetime:**

# %%
visits['session_start'] = pd.to_datetime(visits['session_start'])
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# %% [markdown]
# **Посмотрим на обновлённый датасет visits:**

# %%
visits.head()
# Out:
#         user_id         region   device  channel       session_start  \
# 0  981449118918  United States   iPhone  organic 2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic 2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic 2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop 2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic 2019-05-01 03:33:35
#
#            session_end
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40

# %% [markdown]
# **Мы произвели первичный анализ датасетов, в ходе которого не было выявлено присутствия пропусков или аномальных значений в представленных датасетах. Явные дубликаты также отсутствуют.
# Также мы привели данные в колонках с датой к типу datetime, для удобства дальнейшей обработки поменяли названия колонок.
# Таким образом, произведена предварительная обработка данных и датасеты подготовлены к дальнейшей работе.**

# %% [markdown]
# <div class="alert alert-info">
#
# ## ОПРЕДЕЛЕНИЕ ФУНКЦИЙ ДЛЯ РАСЧЁТА БИЗНЕС-ПОКАЗАТЕЛЕЙ

# %% [markdown]
# **Зададим функции для расчёта и анализа LTV, ROI, удержания и конверсии.**
#
# Это функции для вычисления значений метрик:
#
# - `get_profiles()` — для создания профилей пользователей,
# - `get_retention()` — для подсчёта Retention Rate,
# - `get_conversion()` — для подсчёта конверсии,
# - `get_ltv()` — для подсчёта LTV.
#
# А также функции для построения графиков:
#
# - `filter_data()` — для сглаживания данных,
# - `plot_retention()` — для построения графика Retention Rate,
# - `plot_conversion()` — для построения графика конверсии,
# - `plot_ltv_roi` — для визуализации LTV и ROI.

# %% [markdown]
# ### Зададим функции для вычисления значений метрик:

# %%
#зададим функцию для создания профилей пользователей

def get_profiles(sessions, orders, ad_costs):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %%
#зададим функцию для подсчёта Retention Rate

def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
# зададим функцию для подсчёта конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
# зададим функцию для подсчёта LTV

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# ### Зададим функции для построения графиков:

# %%
#зададим функцию для сглаживания данных

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %%
#зададим функцию построения графика Retention Rate

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %%
#зададим функцию для построения графика конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %%
#зададим функцию для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# **Мы задали все требуемые функции и готовы приступить к исследовательскому анализу данных
# На стадии предобработки не было выявлено пропусков и явных дубликатов. Колонки с датами были приведену к соответствующим типам  datetime.**

# %% [markdown]
# <div class="alert alert-info">
#
# ## ИССЛЕДОВАТЕЛЬСКИЙ АНАЛИЗ ДАННЫХ

# %% [markdown]
# **В рамках исследовательского анализа, определим следующие задачи:**
#
# - составим профили пользователей. Определим минимальную и максимальную даты привлечения пользователей;
# - выясним, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Построим таблицу, отражающую количество пользователей и долю платящих из каждой страны;
# - узнаем, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Построим таблицу, отражающую количество пользователей и долю платящих для каждого устройства;
# - изучим рекламные источники привлечения и определите каналы, из которых пришло больше всего платящих пользователей. Построим таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.
#
# **После каждого пункта сформулируем предварительные выводы.**

# %% [markdown]
# ### Составим профили пользователей

# %%
# построим профили пользоваелей по двум наборам данных

profiles = get_profiles(visits, orders, costs)

# %%
display (profiles)
# Out:
#              user_id            first_ts       channel  device         region  \
# 0             599326 2019-05-07 20:58:57      FaceBoom     Mac  United States
# 1            4919697 2019-07-09 12:46:07      FaceBoom  iPhone  United States
# 2            6085896 2019-10-01 09:58:33       organic  iPhone         France
# 3           22593348 2019-08-22 21:35:48    AdNonSense      PC        Germany
# 4           31989216 2019-10-02 00:07:44       YRabbit  iPhone  United States
# ...              ...                 ...           ...     ...            ...
# 150003  999956196527 2019-09-28 08:33:02        TipTop  iPhone  United States
# 150004  999975439887 2019-10-21 00:35:17       organic      PC             UK
# 150005  999976332130 2019-07-23 02:57:06        TipTop  iPhone  United States
# 150006  999979924135 2019-09-28 21:28:09  MediaTornado      PC  United States
# 150007  999999563947 2019-10-18 19:57:25       organic  iPhone  United States
#
# ...

# %%
#определим минимальную дату привлечения пользователей

min(profiles.dt)
# Out:
# datetime.date(2019, 5, 1)

# %%
#определим максимальную дату привлечения пользователей

max(profiles.dt)
# Out:
# datetime.date(2019, 10, 27)

# %% [markdown]
# **Как мы можем видеть, всего найдено 150 007 уникальных пользователей. Минимальная дата привлечения - 01 мая 2019 года, максимальная - 27 октября 2019 года.
# Таким образом, нам представлены данные за полгода наблюдений.**

# %% [markdown]
# ### Выясним, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей.

# %%
countries = profiles.pivot_table (index = 'region', values='payer', aggfunc=['count', 'mean'])
countries.columns = ['quantity_of_users', 'paying_users']
countries = countries.sort_values(by='quantity_of_users', ascending=False)

# %%
countries
# Out:
#                quantity_of_users  paying_users
# region
# United States             100002      0.069019
# UK                         17575      0.039829
# France                     17450      0.037994
# Germany                    14981      0.041119

# %%
#отразим на графике только долю платящих клиентов

figure(figsize=(15, 8))
plt.bar(x=countries.index, height=countries['paying_users'],)
plt.title('Доли платящих пользователей по каждой стране')
plt.xlabel('Страна')
plt.ylabel('Доля платящих клиентов')
plt.show()

# %% [markdown]
# **Можем сделать вывод, что максимальное количество пользователей приходит из США, минимальное - из Германии.
# А вот по доле платящих клиентов, среди всех зашедших, картина несколько иная: лидером здесь, по прежнему являются США, но аутсайдером выступает уже Франция.**

# %% [markdown]
# ### Выясним, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи.

# %%
devices = profiles.pivot_table (index = 'device', values='payer', aggfunc=['count', 'mean'])
devices.columns = ['quantity_of_users', 'paying_users']
devices = devices.sort_values(by='quantity_of_users', ascending=False)

# %%
devices
# Out:
#          quantity_of_users  paying_users
# device
# iPhone               54479      0.062079
# Android              35032      0.058518
# PC                   30455      0.050468
# Mac                  30042      0.063644

# %%
#отразим на графике только долю платящих клиентов

figure(figsize=(15, 8))
plt.bar(x=devices.index, height=devices['paying_users'],)
plt.title('Доли платящих пользователей по каждому устройству')
plt.xlabel('Устройство')
plt.ylabel('Доля платящих клиентов')
plt.show()

# %% [markdown]
# **Как видим, наибольшее количество пользователей заходит с Айфонов, наименьшее - с устройств Mac.
# Однако доля платящих пользователей максимальна именно среди пользователей Mac, минимальное же - у пользователей PC.
# В целом, доля платящих пользователей выше у тех, кто использует продукцию Apple.**

# %% [markdown]
# ### Изучим рекламные источники привлечения и определим каналы, из которых пришло больше всего платящих пользователей.

# %%
channels = profiles.pivot_table (index = 'channel', values='payer', aggfunc=['count', 'mean'])
channels.columns = ['quantity_of_users', 'paying_users']
channels = channels.sort_values(by='quantity_of_users', ascending=False)

# %%
channels
# Out:
#                     quantity_of_users  paying_users
# channel
# organic                         56439      0.020553
# FaceBoom                        29144      0.122049
# TipTop                          19561      0.096007
# OppleCreativeMedia               8605      0.027077
# LeapBob                          8553      0.030633
# WahooNetBanner                   8553      0.052964
# RocketSuperAds                   4448      0.079137
# MediaTornado                     4364      0.035747
# YRabbit                          4312      0.038265
# AdNonSense                       3880      0.113402
# lambdaMediaAds                   2149      0.104700

# %%
#отразим на графике только долю платящих клиентов

figure(figsize=(20, 10))
plt.bar(x=channels.index, height=channels['paying_users'],)
plt.title('Доли платящих пользователей по каждому источнику')
plt.xlabel('Канал')
plt.ylabel('Доля платящих клиентов')
plt.show()

# %% [markdown]
# **Судя по получившейся таблице, наибольшее количество пользователей пришло из канала Organic, т.е. по сути, это "бесплатные пользователи", с точки зрения стоимости привлечения (САС), однако и доля платящих пользователей среди них - самая незначительная (порядка 2%).
# В то же время пользователи, пришедшие с FaceBoom, находясь на втором месте по общему количеству пользователей, демонстрируют самый высокий процент именно платящих пользователей (порядка 12%), что заставляет обратить на этот канал более пристальное внимание как на наиболее перспективный.
# Минимальное количество пользователей пришло с каналов AdNonSense и LambdaMediaAds. При всём прочем, эти каналы находятся на втором и третьем местах по количеству платящих пользователей, что также делает переспективным их дальнейшее изучение.**

# %% [markdown]
# **Дополнительно проанализируем, из каких каналов шёл основной траффик клиентов применительно к странам:**

# %%
chan_country = profiles.pivot_table(index='region', columns='channel', values='user_id', aggfunc='count').fillna(0)

# %%
chan_country
# Out:
# channel        AdNonSense  FaceBoom  LeapBob  MediaTornado  \
# region
# France             1366.0       0.0   2988.0           0.0
# Germany            1219.0       0.0   2519.0           0.0
# UK                 1295.0       0.0   3046.0           0.0
# United States         0.0   29144.0      0.0        4364.0
#
# channel        OppleCreativeMedia  RocketSuperAds   TipTop  WahooNetBanner  \
# region
# France                     2991.0             0.0      0.0          2971.0
# Germany                    2562.0             0.0      0.0          2579.0
# UK                         3052.0             0.0      0.0          3003.0
# United States                 0.0          4448.0  19561.0             0.0
#
# channel        YRabbit  lambdaMediaAds  organic
# region
# France             0.0           742.0   6392.0
# Germany            0.0           649.0   5453.0
# UK                 0.0           758.0   6421.0
# United States   4312.0             0.0  38173.0

# %%
#отразим графически

plt.figure(figsize=(20, 10))
sns.heatmap(chan_country, annot=True, fmt='g')
plt.show()

# %% [markdown]
# **Как видим, наибольший траффик в США идёт через каналы FaceBoom и TipTop (если мы учитываем платные каналы).
# Траффик остальных платных каналов довольно скромен на общем фоне, в том числе в странах Европы в целом.**

# %% [markdown]
# **В качестве некоего общего вывода по итогам исследовательского анализа, можно отметить тот факт, что основная масса новых клиентов (больше трети) приходит из канала Organic, что может свидетельствовать о недостаточных усилиях по организации рекламных компаний в платных, но при этом приводящих гораздо более платёжеспособную аудиторию, каналах.
# Наиболее "платёжеспособными"странами являются США и Германия, что делает целесообразными рекламные компании именно в этих странах, в первую очередь.
# Видна чёткая картина разделения пользователей США и Европы - общее количество пользователей из США кратно больше пользователей любой из оставшихся стран. Из этого можно сделать вывод о недостаточных усилиях по привлечению клиентов из Великобритании, Франции и Германии, т.е. недостаточная работа с европейскими пользователями.
# Наконец, аудитория, использующая устройства iPhone и Mac, является наиболее платёжеспособной. Это может быть связано как с качество аудитории, так и с наибольшей проработанностью пользовательского интерфейса именно для устройств Apple.
# Говоря о основных каналах траффика. следует выделить FaceBoom и TipTop, причём от обоих идёт траффик только лишь в США.**

# %% [markdown]
# <div class="alert alert-info">
#
# ## МАРКЕТИНГОВЫЙ АНАЛИЗ

# %% [markdown]
# **В рамках маркетингового анализа, определим следующие задачи:**
#
# - посчитаем общую сумму расходов на маркетинг;
# - выясним, как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник;
# - построим визуализацию динамики изменения расходов во времени (по неделям и месяцам) по каждому источнику;
# - узнаем, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника. Используем профили пользователей.
#
# **По итогам, напишем промежуточные выводы.**

# %% [markdown]
# ### Посчитаем общую сумму расходов на маркетинг.

# %%
profiles.acquisition_cost.sum()
# Out:
# 105497.29999999999

# %% [markdown]
# **Общая сумма расходов за наблюдаемый полугодовой период составила порядка 105497 условных единиц.**

# %% [markdown]
# ### Выясним, как траты распределены по рекламным источникам.

# %%
spending_by_sources = profiles.groupby('channel').agg({'acquisition_cost':'sum'}).sort_values(by='acquisition_cost',
                                                                                              ascending=False)

# %%
spending_by_sources
# Out:
#                     acquisition_cost
# channel
# TipTop                      54751.30
# FaceBoom                    32445.60
# WahooNetBanner               5151.00
# AdNonSense                   3911.25
# OppleCreativeMedia           2151.25
# RocketSuperAds               1833.00
# LeapBob                      1797.60
# lambdaMediaAds               1557.60
# MediaTornado                  954.48
# YRabbit                       944.22
# organic                         0.00

# %%
#отобразим полученную информацию графически

figure(figsize=(20, 12))
spending_by_sources['acquisition_cost'].plot(kind='pie', autopct='%1.0f%%')
plt.title('Распределение затрат по рекламным источникам')
plt.ylabel('Затраты')
plt.show()

# %% [markdown]
# **Как видим, безусловный лидер по маркетинговым затратам - канал TipTop, за ним следом - с почти двукратным отрывом - FaceBoom.
# Два последних места среди платных каналов делят MediaTornado и YRabbit.
# Канал Organic является традиционно "бесплатным".**

# %% [markdown]
# ### Построим визуализацию динамики изменения расходов во времени по каждому источнику.

# %%
#для дальнешего анализа, выделим недели в отдельную колонку

profiles['week'] = profiles['first_ts'].dt.isocalendar().week

# %%
#сгруппируем данные по неделям

weeks = profiles.pivot_table(index='channel', columns='week', values='acquisition_cost', aggfunc='sum')

# %%
weeks
# Out:
# week                    18      19      20      21        22       23  \
# channel
# AdNonSense          211.05  273.00  265.65  266.70   202.650   102.90
# FaceBoom            535.70  750.20  755.70  722.70  1208.900  1081.30
# LeapBob              16.80   31.71   26.67   26.67    65.520    66.99
# MediaTornado         38.64   61.68   59.04   50.16    36.960    27.60
# OppleCreativeMedia   24.00   34.50   27.50   34.25    81.750    79.50
# RocketSuperAds       99.45  139.23  138.06  131.04    97.695    76.05
# TipTop              347.00  470.00  454.00  801.80  1421.200  1223.60
# WahooNetBanner       49.20   92.40   90.00   79.20   179.400   196.80
# YRabbit              52.20   75.90   69.30   65.40    49.800    25.80
# lambdaMediaAds       81.60  103.20   90.40  119.20    83.200    35.20
# organic               0.00    0.00    0.00    0.00     0.000     0.00
#
# week                     24       25       26        27  ...       34  \
# ...

# %%
#построим визуализацию по неделям

weeks.T.plot(grid=True, figsize=(20, 10))
plt.xlabel('Недели')
plt.ylabel('Расходы')
plt.title('Динамика расходов по каналам с разбивкой по неделям')
plt.show()

# %% [markdown]
# **Мы видим два основных канала привлечения траффика: TipTop (первое место) и FaceBoom (второе место). Затраты по этим двум каналам в целом демонстрируют тенденцию к постоянному увеличению. Пик расходов за наблюдаемый период приходится на 39-ю неделю.
# Затраты на остальные каналы, при этом не демонстрируют выраженной динамики и остаются на стабильно низком уровне.**
#
# **Теперь посмотрим на разбивку расходов по месяцам:**

# %%
months = profiles.pivot_table(index='channel', columns='month', values='acquisition_cost', aggfunc='sum')

# %%
months
# Out:
# month               2019-05-01  2019-06-01  2019-07-01  2019-08-01  \
# channel
# AdNonSense             1169.70     538.650      504.00      579.60
# FaceBoom               3524.40    5501.100     5294.30     6274.40
# LeapBob                 140.28     314.580      313.53      369.81
# MediaTornado            238.56     138.000      138.48      154.56
# OppleCreativeMedia      169.75     370.000      366.50      439.25
# RocketSuperAds          577.98     325.715      252.07      253.11
# TipTop                 2981.00    6675.600     8410.20    11202.00
# WahooNetBanner          418.80     921.000      851.40     1040.40
# YRabbit                 299.70     106.200       97.38      124.74
# lambdaMediaAds          458.40     199.200      219.20      220.00
# organic                   0.00       0.000        0.00        0.00
#
# month               2019-09-01  2019-10-01
# channel
# AdNonSense              581.70     537.600
# FaceBoom               6114.90    5736.500
# ...

# %%
months.T.plot(grid=True, figsize=(20, 10))
plt.xlabel('Месяцы')
plt.ylabel('Расходы')
plt.title('Динамика расходов по каналам с разбивкой по месяцам')
plt.show()

# %% [markdown]
# **На этом графике наблюдаем ту же картину, что и на разбивке по неделям, но укрупнённо - так же выделяются два очевидным лидера - TipTop и FaceBoom.
# Здесь мы, в частности, видим, что пик расходов по этим двум лидерам наблюдается в сентябре, после чего идёт некоторый спад.
# Оставшиеся каналы демонстрируют минимальную динамику.**

# %% [markdown]
# ### Узнаем, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника.

# %%
# для начала, исключим пользователей, пришедших с канала Organic, т.к.на них не было потрачено ничего

profiles1 = profiles.query('channel != "organic"')

# %%
#рассчитаем средний САС на одного пользователя для всего проекта

average_cac = sum(profiles1.acquisition_cost) / len(profiles1.user_id)

# %%
average_cac
# Out:
# 1.127481323942928

# %% [markdown]
# **Средняя стоимость привлечения одного посетителя из платных каналов за исследуемый период составила, таким образом, 1,13 условных единиц.
# Теперь посчитаем сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника:**

# %%
profiles1 = profiles1.pivot_table(index='channel', values='acquisition_cost', aggfunc=['count', 'sum'])

# %%
#переименуем колонки, дабы убрать мультииндекс

profiles1.columns = ['count', 'costs']

# %%
#сформируем новый столбец - сас и отсортируем его по стоимости

profiles1['cac'] = profiles1['costs'] / profiles1['count']
profiles1 = profiles1.sort_values(by='cac', ascending=False)

# %%
profiles1
# Out:
#                     count     costs       cac
# channel
# TipTop              19561  54751.30  2.799003
# FaceBoom            29144  32445.60  1.113286
# AdNonSense           3880   3911.25  1.008054
# lambdaMediaAds       2149   1557.60  0.724802
# WahooNetBanner       8553   5151.00  0.602245
# RocketSuperAds       4448   1833.00  0.412095
# OppleCreativeMedia   8605   2151.25  0.250000
# YRabbit              4312    944.22  0.218975
# MediaTornado         4364    954.48  0.218717
# LeapBob              8553   1797.60  0.210172

# %%
#отразим всё это графически

figure(figsize=(20, 10))
plt.bar(x=profiles1.index, height=profiles1['cac'],)
plt.title('Средняя стоимость привлечения с разбивкой по источникам')
plt.xlabel('Канал')
plt.ylabel('CAC')
plt.show()

# %% [markdown]
# **Мы видим, что по затратности на привлечение с большим отрывом лидирует канал TipTop, более чем в 2 раза обгоняя FaceBoom и AdNonSense.
# Тройка самых малозатратных - YRabbit, MediaTornado и LeapBob.**

# %% [markdown]
# **Подводя некоторый промежуточный итог, мы видим, что наибольшие маркетинговые расходы идут на два основных канала - TiTop и FaceBoom.
# При этом TipTop имеет самую высокую стоимость привлечения одного посетителя и не самую высокую долю платящих посетителей (порядка 10%), уступая по обоим этим показателям FaceBoom'у (стоимость привлечения более, чем в 2 раза ниже, процент платящих покупателей - 12%). При этом траффик пользователей, привлечённых FaceBoom'ом выше, чем ТipTop'ом (29144 против 19561).
# Всё это даёт основание усомниться в рациональности выделения столь значительных средств на TipTop.
# Представляется более рациональным направить дополнительные средства на развитие каналов AdNonSense и lambdaMediaAds, которые, при более низкой стоимости привлечения, демонстрируют довольно высокий процент платящих пользователей (11% и 10% соответственно).**

# %% [markdown]
# <div class="alert alert-info">
#
# ## ОЦЕНИМ ОКУПАЕМОСТЬ РЕКЛАМЫ

# %% [markdown]
# **Используя графики LTV, ROI и CAC, проанализируем окупаемость рекламы. Будем считать, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения.**
#
# - проанализируем окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI;
# - проверим конверсию пользователей и динамику её изменения. То же самое сделаем с удержанием пользователей. Построим и изучим графики конверсии и удержания;
# - проанализируем окупаемость рекламы с разбивкой по устройствам. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI;
# - проанализируем окупаемость рекламы с разбивкой по странам. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируем окупаемость рекламы с разбивкой по рекламным каналам. Построим графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
#
# **Ответьте на следующие вопросы:**
#     - Окупается ли реклама, направленная на привлечение пользователей в целом?
#     - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
#     - Чем могут быть вызваны проблемы окупаемости?
#
# **По итогам, напишем вывод, опишем возможные причины обнаруженных проблем и промежуточные рекомендации для рекламного отдела.**

# %% [markdown]
# ### Проанализируем окупаемость рекламы c помощью графиков LTV и ROI, а также графиков динамики LTV, CAC и ROI.

# %%
#зададим момент анализа и горизонт анализа

observation_date = datetime(2019, 11, 1).date()
horizon_days = 14

# %%
#поскольку органические пользователи условно "бесплатны", исключаем их из анализируемых данных

profiles1 = profiles.query('channel != "organic"')

# %%
#рассчитаем LTV и ROI

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(profiles1,
                                                                      orders,
                                                                      observation_date,
                                                                      horizon_days)

# %%
#построим графики

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# **Исходя из графиков, можно сделать выводы о том, что:**
#
#
# **1) реклама не окупается (ROI в конце двухнедельного цикла - лишь в районе 80%);
# 2) САС демонстрирует ощутимое увеличение, значит возможно дело - в увеличении рекламного бюджета;
# 3) при этом ROI демонстрирует динамику к снижению, что соглаусется с выводом об увеличении рекламного бюджета;
# 4) LTV достаточно стабилен, присутствуют сезонные колебания, но явных аномалий не наблюдается.**

# %% [markdown]
# ### Проверим конверсию пользователей и динамику её изменения. То же самое сделаем с удержанием пользователей. Построим и изучим графики конверсии и удержания.

# %%
#проверим общую конверсию и динамику её изменения

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles1, orders, observation_date, horizon_days)


#строим график изменения коверсии

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# **Общая конверсия не показывает каких-либо аномалий - рост устойчив. График динамики в целом равномерный.
# Посмотрим, что с общими показателями удержания:**

# %%
#запрашиваем показатели удержания
retention_raw, retention_grouped, retention_history = get_retention(
    profiles1, visits, observation_date, horizon_days)

#строим график
plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# **Кривая платящих пользователей находится выше, чем кривая неплатящих, а форма распределений близка к обратно-экспоненциальной, что говорит нам о правильности кривых удержания.
# В целом, картина не показывает аномалий.**

# %% [markdown]
# ### Проанализируем окупаемость рекламы с разбивкой по устройствам.

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles1, orders, observation_date, horizon_days, dimensions=['device'])

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# **Судя по представленным данным, окупаются только пользователи PC, близки к окупаемости пользователи Android.
# При этом стоимость затрат на рекламу стабильно растёт, особенно для владельце Mac и iPhone.
# LTV стабилен везде.**

# %% [markdown]
# **Проверим конверсию и удержание пользователей с разбивкой по устройствам.**

# %%
#смотрим конверсию

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles1, orders, observation_date, horizon_days, dimensions=['device'])


plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# **Здесь мы можем видеть, что наибольшая конверсия - у обладателей Mac и iPhone, наименьшая - у владельцев PC.
# Возможно, приложение успешнее и понятнее реализовано на платформе IOS, чем на прочих.**

# %%
#смотрим показатели удержания


retention_raw, retention_grouped, retention_history = get_retention(
    profiles1, visits, observation_date, horizon_days, dimensions=['device'])


plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# **В плане удержания пользователей не выявлено существенной разницы уровня удержания от используемого устройства.
# Вероятно, успешно освоив функционал на начальном этапе, далее без особых проблем его используют владельцы всех представленных устройств.**

# %% [markdown]
# ### Проанализируем окупаемость рекламы с разбивкой по странам.

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles1, orders, observation_date, horizon_days, dimensions=['region'])

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %%
pd.set_option('display.max_rows', 15)

# %% [markdown]
# **Видим, что реклама окупилась везде, кроме США. LTV стабильно во всех странах, с явным доминированием Соединённых Штатов.
# Стоимость привлечения новых пользователей, начиная с июня, со временем падает везде, кроме США.**

# %% [markdown]
# **Проверим конверсию и удержание пользователей с разбивкой по странам.**

# %%
#смотрим конверсию

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles1, orders, observation_date, horizon_days, dimensions=['region'])


plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# **Следует отметить высокие показатели конверсии в США и сравнительно низкие - более, чем в 2 раза, в странах Европы.
# Возможно, проводится более успешная рекламная кампания по привлечению именно платящих клиентов именно в США.**

# %%
#смотрим показатели удержания


retention_raw, retention_grouped, retention_history = get_retention(
    profiles1, visits, observation_date, horizon_days, dimensions=['region'])


plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# **А вот картина с удержанием совершенно другая - здесь США выступают явным аутсайдером среди платящих пользователей.**

# %% [markdown]
# **Таким образом, произведя разбивку по регионам, мы видим более плотный приток платящих клиентов из США. В то же время, показатели удержания данных клиентов достаточно низкие, т.е. их много приходят, покупают, но сравнительно мало потом возвращаются и продолжают производить покупки.
# В Европе ситуация обратная - при скромном изначальном притоке клиентов, удерживаются они гораздо лучше.**

# %% [markdown]
# ### Проанализируем окупаемость рекламы с разбивкой по рекламным каналам.

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles1, orders, observation_date, horizon_days, dimensions=['channel'])

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# **Видим, что реклама окупилась во всех источниках, кроме TipTop, AdNonSense и FaceBoom. При этом, начиная с середины мая, резко увеличиваются расходы на рекламу в TipTop, на фоне отсутствия существенных изменений в стоимости прочих каналов.
# LTV относительно устойчив по представленным каналам, но наблюдаются 2 явных лидера - TipTop и LambdaMediaAds.**

# %% [markdown]
# **Проверим конверсию и удержание пользователей с разбивкой по каналам привлечения.**

# %%
#смотрим конверсию

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles1, orders, observation_date, horizon_days, dimensions=['channel'])


plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# **Явных аномалий в конверсии не наблюдается.
# Стоит отметить наиболее высокий уровень конверсии у FaceBoom'a.**

# %%
#смотрим показатели удержания


retention_raw, retention_grouped, retention_history = get_retention(
    profiles1, visits, observation_date, horizon_days, dimensions=['channel'])


plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# **Стоит отметить низкие показатели удержания каналов AdNonSense и YRabbit.**

# %% [markdown]
# ### Ответы на вопросы

# %% [markdown]
# >  <font size="4">Окупается ли реклама, направленная на привлечение пользователей в целом?</b></font>
# В целом мы видим. что реклама не окупается, достигая окупаемости на уровне чуть выше 80% по итогам 14 дневного горизонта анализа.
#
# >  <font size="4">Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?</b></font>
# Судя по представленным данным, окупаются только пользователи PC, близки к окупаемости пользователи Android, при этом стоимость затрат на рекламу стабильно растёт, особенно для владельце Mac и iPhone.
# Что касается регионов, реклама окупилась везде, кроме США, где стоимость привлечения новых клиентов стабильно растёт, начиная с июня, при падении этой стоимости во всех остальных странах.
# Также реклама не окупилась в следующих каналах привлечения: TipTop, AdNonSense и FaceBoom. При этом, начиная с середины мая, резко увеличиваются расходы на рекламу в TipTop, на фоне отсутствия существенных изменений в стоимости прочих каналов.
#
# >  <font size="4">Чем могут быть вызваны проблемы окупаемости?</b></font>
# Проблемы окупаемости могут быть вызваны неэффективным расходованием средств расходов на рекламу.
# При этом общий САС демонстрирует ощутимое увеличение, а ROI показывает динамику к снижению, что соглаусется с выводом об увеличении рекламного бюджета значит возможно дело - в увеличении рекламного бюджета.
# Особенно заметен рост расходов на рекламу в США, а также в канале TipTop.

# %% [markdown]
# <div class="alert alert-info">
#
# ## ОБЩИЙ ВЫВОД

# %% [markdown]
# - Выделим причины неэффективности привлечения пользователей.
# - Сформулируем рекомендации для отдела маркетинга.

# %% [markdown]
# <div class="alert alert-info">
#
#
# **Нами был рассмотрен датасет, хранящий информацию о данные о пользователях развлекательного приложения Procrastinate Pro+. , привлечённых с 1 мая по 27 октября 2019 года**
#
# ---
#
# **Подводя итоги нашего исследования, можно сказать, что наблюдается чёткая картина разделения пользователей США и Европы - общее количество пользователей из США кратно больше пользователей любой из оставшихся стран. Из этого можно сделать вывод о недостаточных усилиях по привлечению клиентов из Великобритании, Франции и Германии, т.е. недостаточная работа с европейскими пользователями**
#
# ---
#
# **Следует отметить высокие показатели конверсии в США и сравнительно низкие - более, чем в 2 раза, в странах Европы.
# Возможно, проводится более успешная рекламная кампания по привлечению именно платящих клиентов именно в США.
# А  вот картина с удержанием совершенно другая - здесь США выступают явным аутсайдером среди платящих пользователей.
# Таким образом, произведя разбивку по регионам, мы видим более плотный приток платящих клиентов из США. В то же время, показатели удержания данных клиентов достаточно низкие, т.е. их много приходят, покупают, но сравнительно мало потом возвращаются и продолжают производить покупки.
#     В Европе ситуация обратная - при скромном изначальном притоке клиентов, удерживаются они гораздо лучше.
#     При этом, в рамках двухнедельного горизонта анализа мы видим, что реклама окупилась везде, кроме США.
#     Стоимость привлечения новых пользователей, начиная с июня, со временем падает везде, кроме США.**
#
# **Стоит отметить  тот факт, что наибольшее количество пользователей пришло из канала Organic, однако и доля платящих пользователей среди них - самая незначительная (порядка 2%).
#     Столь высокая процент посетителей канала Organic может свидетельствовать о потенциальной востребованности продукта (пользователи приходят даже без специальных рекламных акций), с одной стороны, и о недостаточной эффективности организации рекламных компаний в платных, но при этом приводящих гораздо более платёжеспособную аудиторию, каналах.**
#
# **Аудитория, использующая устройства iPhone и Mac, является наиболее платёжеспособной. Это может быть связано как с качеством аудитории, так и с наибольшей проработанностью пользовательского интерфейса именно для устройств Apple.**
#
#
# ---
#
#
# **Если говорить о показателях LTV и  ROI в целом, мы видим следующую картину:**
# **1) реклама не окупается (ROI в конце двухнедельного цикла - чуть выше 80%);
# 2) САС демонстрирует ощутимое увеличение, значит возможно дело - в увеличении рекламного бюджета;
# 3) при этом ROI демонстрирует динамику к снижению, что соглаусется с выводом об увеличении рекламного бюджета;
# 4) LTV достаточно стабилен, присутствуют сезонные колебания, но явных аномалий не наблюдается.**
#
#
# ---
#
# **По итогам исследования мы видим, что безусловный лидер по маркетинговым затратам - канал TipTop, за ним следом - с почти двукратным отрывом - FaceBoom.
#     Затраты по этим двум каналам в целом демонстрируют тенденцию к постоянному увеличению. Пик расходов за наблюдаемый период приходится на 39-ю неделю.
#     Затраты на остальные каналы, при этом не демонстрируют выраженной динамики и остаются на стабильно низком уровне.
#     Два последних места среди платных каналов делят MediaTornado и YRabbit.
#     При этом TipTop имеет самую высокую стоимость привлечения одного посетителя и не самую высокую долю платящих посетителей (порядка 10%), уступая по обоим этим показателям FaceBoom'у (стоимость привлечения более, чем в 2 раза ниже, процент платящих покупателей - 12%). При этом траффик пользователей, привлечённых FaceBoom'ом выше, чем ТipTop'ом (29144 против 19561).
#     Видим, что реклама окупилась во всех источниках, кроме TipTop, AdNonSense и FaceBoom. При этом, начиная с середины мая, резко увеличиваются расходы на рекламу в TipTop, на фоне отсутствия существенных изменений в стоимости прочих каналов.
#     Всё это даёт основание усомниться в рациональности выделения столь значительных средств на TipTop.
#     Представляется более рациональным направить дополнительные средства на развитие каналов AdNonSense и lambdaMediaAds, которые, при более низкой стоимости привлечения, демонстрируют довольно высокий процент платящих пользователей (11% и 10% соответственно).
#     Кроме того, мы видим, что весь траффик каналов FaceBoom и TipTop идёт исключительно в США, что вкупе с упомянутыми выше выводами даёт основание говорить о том, что это очень дорогостоящий траффик, с довольно высокой конверсией, но низким удержанием клиентов, т.е. клиенты из этих каналов в основном приходят ради совершения одной-двух покупок.
# Основной рекламный бюджет также уходит на эти два канала. В дополнение ко всему, TipTop демонстрирует постоянную динамику к увеличению стоимости привлекаемых клиентов.
#     Итого основные маркетинговые затраты идут на два канала, привлекающие клиентов с коротким "сроком" жизни, только из США, в то время, как Европа практически не охвачена, при том, что там присутствуют гораздо более дешёвые каналы с неплохой долей платящих клиентов.**
#
# ---
#
# <font size="4"><b>Рекомендации по итогам исследования</b></font>
#     **В качестве рекомендаций мы бы посоветовали перераспределить рекламный бюджет - полностью прекратить сотрудничество с каналом TipTop, как самым затратным и не окупающимся, провести переговоры с FaceBoom на предмет снижения стоимости рекламы.
#     Также необходимо активизировать рекламную деятельность в Европе, как неохваченном, по существу, но довольно перспективном рынке (доля платящих клиентов в Германии - на втором месте после США). Для этого, в частности, можно использовать такие каналы как WahooNetBanner и lambdaMediaAds.**
# </div>
